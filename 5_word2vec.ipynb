# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.692792
# Nearest to with: affected, cosmic, lahoud, heracleidae, detract, theoretically, downey, stunned,
# Nearest to six: bolivar, turntables, curlers, msx, depositing, yankee, jacobsen, indecision,
# Nearest to used: centering, ole, im, impulse, telekinetic, generality, timelines, contemporaries,
# Nearest to would: dict, davros, drowning, leyden, kestrel, advantageous, vincennes, sinauer,
# Nearest to these: doren, classifies, marginalized, ashoka, landscaping, graham, delved, robot,
# Nearest to if: laserdisc, quietly, ipc, unwieldy, projector, bollywood, krush, snows,
# Nearest to war: icann, trolley, overthrows, cumings, overlapping, metzger, toy, reasoned,
# Nearest to american: wheelchair, chauvinism, modification, uua, simmons, waveforms, america, pynchon,
# Nearest to over: geological, rearmament, recruiting, noumenon, unconscious, abraxas, balinese, codons,
# Nearest to such: lair, edgerton, motorways, permission, ulysses, platform, nta, seville,
# Nearest to called: dawn, incited, island, looping, dupuis, dumpster, captors, distorts,
# Nearest to time: wg, handicap, disadvantageous, directv, cochran, weiser, typesetting, rta,
# Nearest to to: dock, disaccharide, alexandria, ya, magnificence, algernon, marathas, rayleigh,
# Nearest to one: surjective, piazza, podcast, nen, cas, riddler, tylor, slalom,
# Nearest to d: aceh, extradited, normalised, densest, nsted, hartmann, finder, yasser,
# Nearest to united: commercialization, coronae, selector, renaming, lojban, safer, tombaugh, runnymede,
# Average loss at step 2000: 4.360064
# Average loss at step 4000: 3.864066
# Average loss at step 6000: 3.793925
# Average loss at step 8000: 3.687520
# Average loss at step 10000: 3.609904
# Nearest to with: in, on, for, commentators, rucker, heracleidae, cosmic, cobalt,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to used: centering, generality, miserable, impulse, subterfuge, seekers, freeview, salah,
# Nearest to would: may, will, can, could, dict, manipulations, ellipse, should,
# Nearest to these: marginalized, detached, ashoka, classifies, they, shocks, geography, trasimene,
# Nearest to if: ipc, laserdisc, observational, offsets, should, holds, ieung, swiss,
# Nearest to war: tennant, dissociatives, parabolic, smokey, atrocities, lane, ricimer, trolley,
# Nearest to american: wheelchair, personae, sportscaster, uua, national, tutelage, guest, french,
# Nearest to over: rearmament, unconscious, skeptic, noumenon, unthinkable, resolvers, donates, geological,
# Nearest to such: pong, toho, wolfgang, known, finds, oversees, areas, siemens,
# Nearest to called: island, incited, managed, foxe, looping, solved, distorts, captors,
# Nearest to time: shades, perils, typesetting, however, wg, amphitryon, disadvantageous, handicap,
# Nearest to to: disaccharide, marking, algernon, marathas, grand, wembley, sanskrit, would,
# Nearest to one: two, three, four, six, eight, exothermic, five, marinus,
# Nearest to d: aceh, b, contributes, patriarchates, melchior, extradited, dealings, ecologist,
# Nearest to united: commercialization, moabites, aerodynamically, tombaugh, runnymede, nabla, culbert, widdecombe,
# Average loss at step 12000: 3.608384
# Average loss at step 14000: 3.568089
# Average loss at step 16000: 3.407760
# Average loss at step 18000: 3.460865
# Average loss at step 20000: 3.543746
# Nearest to with: in, tsushima, for, nattiez, by, into, between, cosmic,
# Nearest to six: eight, seven, five, three, four, nine, two, zero,
# Nearest to used: centering, known, subterfuge, generality, earnings, miserable, received, seekers,
# Nearest to would: may, will, can, could, should, must, might, to,
# Nearest to these: some, many, other, several, marginalized, detached, they, such,
# Nearest to if: though, but, does, when, should, kyrgyz, ipc, energy,
# Nearest to war: lane, smokey, parabolic, dissociatives, trolley, tennant, cups, nineveh,
# Nearest to american: french, scottish, guest, kocher, scotia, thatcher, personae, bear,
# Nearest to over: rearmament, skeptic, unconscious, unthinkable, proportionally, multiplicative, resolvers, clonic,
# Nearest to such: known, well, toho, pong, these, areas, infatuated, fixation,
# Nearest to called: incited, foxe, solved, distorts, island, managed, airport, deciding,
# Nearest to time: typesetting, year, shades, quantity, perils, andorra, backslash, jaws,
# Nearest to to: would, disaccharide, marathas, tba, will, not, grand, rf,
# Nearest to one: four, six, three, two, eight, five, seven, nine,
# Nearest to d: b, aceh, milled, co, sibylla, roofs, outage, geometer,
# Nearest to united: aerodynamically, moabites, tombaugh, commercialization, culbert, runnymede, antonine, widdecombe,
# Average loss at step 22000: 3.504744
# Average loss at step 24000: 3.486994
# Average loss at step 26000: 3.482468
# Average loss at step 28000: 3.477223
# Average loss at step 30000: 3.501107
# Nearest to with: between, tsushima, or, cosmic, under, for, rucker, tienne,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to used: known, found, centering, seen, sardaukar, spoken, topic, miserable,
# Nearest to would: can, may, will, could, should, must, might, to,
# Nearest to these: some, many, several, such, they, other, all, their,
# Nearest to if: when, though, does, but, should, kyrgyz, before, since,
# Nearest to war: lane, ricimer, demolished, maceo, parabolic, smokey, trolley, welch,
# Nearest to american: british, scottish, personae, english, german, french, scotia, and,
# Nearest to over: unconscious, rearmament, proportionally, resolvers, marius, skeptic, unthinkable, multiplicative,
# Nearest to such: well, these, toho, known, pong, infatuated, other, fixation,
# Nearest to called: foxe, incited, island, distorts, managed, airport, solved, named,
# Nearest to time: year, shades, adelaide, grt, names, nietzsche, rendering, backslash,
# Nearest to to: would, can, disaccharide, could, marathas, arches, will, songbook,
# Nearest to one: two, four, seven, eight, three, six, nine, five,
# Nearest to d: b, aceh, co, roofs, elaborated, unanimity, sibylla, dealings,
# Nearest to united: aerodynamically, moabites, commercialization, tombaugh, asroc, culbert, widdecombe, runnymede,
# Average loss at step 32000: 3.501469
# Average loss at step 34000: 3.491313
# Average loss at step 36000: 3.454880
# Average loss at step 38000: 3.299785
# Average loss at step 40000: 3.430247
# Nearest to with: between, by, cosmic, christensen, rucker, syed, for, cobalt,
# Nearest to six: seven, four, eight, five, nine, three, two, one,
# Nearest to used: found, known, spoken, seen, considered, available, able, shown,
# Nearest to would: will, could, may, can, must, should, might, did,
# Nearest to these: many, some, several, such, they, different, those, which,
# Nearest to if: when, though, does, just, weaned, so, then, where,
# Nearest to war: ricimer, welch, dissociatives, maceo, demolished, lane, parabolic, stasis,
# Nearest to american: british, australian, english, scottish, scotia, french, german, japanese,
# Nearest to over: existential, resolvers, skeptic, marius, rearmament, pages, donates, unthinkable,
# Nearest to such: well, these, known, pong, including, infatuated, toho, bayou,
# Nearest to called: named, managed, foxe, incited, distorts, juries, solved, menstruation,
# Nearest to time: year, rendering, quantity, mission, period, grt, suited, nietzsche,
# Nearest to to: tba, would, abandoning, marathas, dock, for, could, will,
# Nearest to one: four, seven, six, eight, three, two, five, nine,
# Nearest to d: b, aceh, co, trophies, elaborated, contributes, UNK, unpaired,
# Nearest to united: aerodynamically, moabites, tombaugh, widdecombe, asroc, antonine, commercialization, culbert,
# Average loss at step 42000: 3.438286
# Average loss at step 44000: 3.452869
# Average loss at step 46000: 3.453173
# Average loss at step 48000: 3.353363
# Average loss at step 50000: 3.384010
# Nearest to with: between, tsushima, rucker, bavarian, cosmic, otimes, cobalt, nonce,
# Nearest to six: eight, seven, nine, three, four, five, two, zero,
# Nearest to used: known, seen, found, able, considered, regarded, written, available,
# Nearest to would: will, could, can, may, must, should, might, did,
# Nearest to these: some, many, both, several, such, those, they, creep,
# Nearest to if: when, though, where, so, although, does, before, weaned,
# Nearest to war: ricimer, dissociatives, maceo, demolished, parabolic, welch, celibacy, ketones,
# Nearest to american: australian, french, scottish, british, international, english, dakota, snapper,
# Nearest to over: nl, rearmament, through, plaintiff, cavalier, existential, radiology, germans,
# Nearest to such: well, these, known, many, pong, described, including, sonatas,
# Nearest to called: named, foxe, incited, managed, technische, juries, airport, recalls,
# Nearest to time: year, rendering, quantity, nin, way, suited, eskimos, cowl,
# Nearest to to: shower, tba, marathas, irregularly, can, arches, would, rayleigh,
# Nearest to one: two, six, eight, seven, three, four, nine, five,
# Nearest to d: b, aceh, co, latte, contributes, e, w, dc,
# Nearest to united: aerodynamically, tombaugh, moabites, widdecombe, antonine, culbert, asroc, anglican,
# Average loss at step 52000: 3.437026
# Average loss at step 54000: 3.423775
# Average loss at step 56000: 3.437774
# Average loss at step 58000: 3.396679
# Average loss at step 60000: 3.394810
# Nearest to with: between, tsushima, by, rucker, into, fibrosis, commentators, nonce,
# Nearest to six: eight, five, four, nine, seven, three, one, zero,
# Nearest to used: known, seen, found, considered, available, spoken, called, described,
# Nearest to would: will, could, may, can, must, should, might, did,
# Nearest to these: some, many, those, several, such, both, they, different,
# Nearest to if: when, though, where, although, before, does, then, because,
# Nearest to war: ricimer, maceo, conceding, celibacy, welch, demolished, lane, dissociatives,
# Nearest to american: australian, british, snapper, scottish, french, dakota, english, german,
# Nearest to over: through, marius, existential, into, further, germans, treble, denard,
# Nearest to such: well, known, including, these, pong, many, fixation, bayou,
# Nearest to called: named, used, foxe, quranic, juries, airport, technische, menstruation,
# Nearest to time: year, quantity, period, rendering, mission, way, nin, names,
# Nearest to to: marathas, dock, would, not, tba, lynyrd, provencal, congestive,
# Nearest to one: six, seven, four, eight, three, nine, two, five,
# Nearest to d: b, aceh, w, e, c, latte, co, dc,
# Nearest to united: aerodynamically, tombaugh, moabites, commercialization, mid, antonine, asroc, anglican,
# Average loss at step 62000: 3.234620
# Average loss at step 64000: 3.251981
# Average loss at step 66000: 3.403896
# Average loss at step 68000: 3.392116
# Average loss at step 70000: 3.351973
# Nearest to with: between, tsushima, rucker, into, cosmic, nonce, within, nattiez,
# Nearest to six: eight, four, nine, seven, five, three, zero, two,
# Nearest to used: known, seen, found, available, described, considered, cited, regarded,
# Nearest to would: will, could, may, can, should, must, might, did,
# Nearest to these: such, many, some, those, several, the, there, are,
# Nearest to if: when, though, where, although, before, then, because, does,
# Nearest to war: ricimer, conceding, dissociatives, maceo, chukchi, sram, welch, renunciation,
# Nearest to american: british, australian, snapper, scottish, english, french, dakota, seventeen,
# Nearest to over: existential, germans, marius, further, treble, through, great, from,
# Nearest to such: these, well, including, known, many, pong, fixation, toho,
# Nearest to called: named, used, foxe, managed, technische, known, spelled, quranic,
# Nearest to time: year, period, mission, rendering, quantity, names, digests, way,
# Nearest to to: will, can, marathas, tba, would, could, cannot, may,
# Nearest to one: six, eight, seven, two, five, four, nine, three,
# Nearest to d: b, aceh, w, dc, e, tajikistan, latte, wesley,
# Nearest to united: aerodynamically, anglican, tombaugh, surrounding, asroc, border, antonine, earliest,
# Average loss at step 72000: 3.373407
# Average loss at step 74000: 3.348263
# Average loss at step 76000: 3.305552
# Average loss at step 78000: 3.353701
# Average loss at step 80000: 3.376244
# Nearest to with: between, tsushima, in, within, among, into, caucus, rucker,
# Nearest to six: five, four, eight, seven, three, nine, two, one,
# Nearest to used: known, seen, available, found, described, cited, spoken, written,
# Nearest to would: will, could, may, can, must, should, might, cannot,
# Nearest to these: those, several, many, such, some, both, examples, are,
# Nearest to if: when, though, before, where, then, although, since, because,
# Nearest to war: ricimer, maceo, volcano, parabolic, conceding, appearances, sram, cups,
# Nearest to american: british, australian, french, scottish, german, english, snapper, manchukuo,
# Nearest to over: existential, germans, between, criminalization, resolvers, through, further, rearmament,
# Nearest to such: well, these, including, known, toho, certain, hieroglyphic, many,
# Nearest to called: named, used, known, quranic, foxe, swore, managed, defined,
# Nearest to time: year, period, mission, betters, office, quantity, title, carangi,
# Nearest to to: dock, marathas, betsy, songbook, shower, archived, tba, disaccharide,
# Nearest to one: seven, six, two, four, eight, five, three, nine,
# Nearest to d: b, aceh, w, f, dc, tajikistan, e, trophies,
# Nearest to united: aerodynamically, border, anglican, tombaugh, earliest, controlling, asroc, antonine,
# Average loss at step 82000: 3.408982
# Average loss at step 84000: 3.409644
# Average loss at step 86000: 3.387424
# Average loss at step 88000: 3.356941
# Average loss at step 90000: 3.364189
# Nearest to with: between, tsushima, in, by, within, during, rucker, against,
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to used: known, seen, found, available, described, called, applied, cited,
# Nearest to would: could, will, might, can, must, should, may, did,
# Nearest to these: some, many, several, those, such, all, are, shovel,
# Nearest to if: when, though, where, since, before, although, then, because,
# Nearest to war: parabolic, conceding, cups, ricimer, sram, ketones, celibacy, ganymede,
# Nearest to american: british, french, australian, english, scottish, german, snapper, japanese,
# Nearest to over: existential, germans, nl, further, through, donates, between, resolvers,
# Nearest to such: well, these, known, including, certain, pong, described, drinkers,
# Nearest to called: named, used, known, quranic, swore, menstruation, juries, spelled,
# Nearest to time: year, period, took, carangi, mission, title, firebird, digests,
# Nearest to to: dock, would, will, tba, wembley, shower, rayleigh, must,
# Nearest to one: seven, eight, two, four, six, three, five, nine,
# Nearest to d: b, aceh, trophies, tajikistan, fuss, cavendish, deceleration, co,
# Nearest to united: aerodynamically, border, controlling, anglican, following, tombaugh, asroc, mid,
# Average loss at step 92000: 3.397247
# Average loss at step 94000: 3.256761
# Average loss at step 96000: 3.361522
# Average loss at step 98000: 3.242371
# Average loss at step 100000: 3.359651
# Nearest to with: between, tsushima, within, by, otimes, gulfs, including, cma,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to used: found, known, available, seen, sold, applied, referred, spoken,
# Nearest to would: could, will, should, might, can, may, must, cannot,
# Nearest to these: several, many, some, those, all, various, different, multiple,
# Nearest to if: when, though, where, although, before, since, because, then,
# Nearest to war: ricimer, cups, parabolic, conceding, ganymede, sram, wars, celibacy,
# Nearest to american: british, australian, french, scottish, english, canadian, snapper, metafont,
# Nearest to over: existential, between, donates, skeptic, nl, resolvers, terrier, through,
# Nearest to such: well, known, including, these, futurists, lookup, certain, many,
# Nearest to called: named, used, known, swore, referred, quranic, spelled, glock,
# Nearest to time: year, period, way, quantity, week, cbt, nin, kind,
# Nearest to to: will, could, can, marathas, anxiolytics, tba, must, would,
# Nearest to one: seven, two, four, eight, six, five, nine, three,
# Nearest to d: b, nancy, unpaired, aceh, contributes, tajikistan, quad, co,
# Nearest to united: aerodynamically, border, controlling, anglican, following, asroc, mid, earliest,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
final_embeddings[1]
# Out:
# array([  8.13065246e-02,  -1.77025855e-01,  -4.57827002e-02,
#         -2.01711059e-02,   6.01594225e-02,   5.48890010e-02,
#          1.80422574e-01,   8.91144797e-02,  -1.26875956e-02,
#          1.46366749e-03,   5.83203323e-02,  -7.87065253e-02,
#         -2.00363416e-02,   6.14650585e-02,   6.26326054e-02,
#          9.85416397e-02,   8.34298655e-02,  -1.49534985e-01,
#         -1.56843677e-01,   4.44722101e-02,   3.40045765e-02,
#          4.77805510e-02,   3.43344286e-02,   6.86188862e-02,
#          1.75095007e-01,  -8.99511501e-02,  -3.12589146e-02,
#         -5.17980456e-02,  -1.66619457e-02,  -1.12004280e-02,
#          2.16621812e-02,   1.50165588e-01,  -3.13790798e-01,
#         -1.19472526e-01,   1.59082133e-02,  -2.85662487e-02,
#         -1.93543714e-02,   6.10228302e-03,  -1.33545145e-01,
#         -1.58305928e-01,  -1.73381772e-02,  -3.73060256e-02,
#          1.01401389e-01,   1.88339744e-02,  -3.93551178e-02,
#          1.28995955e-01,   9.66096222e-02,  -2.57742833e-02,
#          1.26834825e-01,   2.88828346e-03,   9.25916284e-02,
#         -7.36272559e-02,  -7.18186274e-02,   3.53428312e-02,
#         -2.85915360e-02,   4.65401672e-02,  -3.43532450e-02,
#          2.69132465e-01,   7.20444508e-03,  -6.02096727e-04,
#         -3.48948166e-02,   1.46401925e-02,   4.56746705e-02,
#          9.47561041e-02,  -4.34111394e-02,  -7.19712302e-02,
#         -7.09142014e-02,  -7.10361004e-02,  -9.02636945e-02,
#         -6.41971305e-02,   1.07516199e-02,   1.36694819e-01,
#         -1.20046131e-01,   1.69729162e-02,   6.32228255e-02,
#         -1.66478939e-02,  -5.62192276e-02,  -5.57642803e-02,
#         -2.05871500e-02,  -1.79470003e-01,   1.15410961e-01,
#         -7.57626519e-02,  -1.34350648e-02,   7.81598017e-02,
#          5.10975420e-02,   4.47097756e-02,   1.87052101e-01,
#         -1.66584626e-02,  -1.66376829e-01,  -9.50166807e-02,
#         -5.79325780e-02,   2.12794524e-02,  -5.73477857e-02,
#         -6.04796298e-02,   8.88311333e-05,   1.97397083e-01,
#          4.21780795e-02,  -5.57621084e-02,   1.21299848e-01,
#         -6.75890520e-02,   1.35900468e-01,  -5.30620292e-03,
#          1.74008906e-01,  -7.75622427e-02,  -2.79858857e-02,
#         -7.66449608e-03,  -3.92597243e-02,   1.04602445e-02,
#          4.11720239e-02,   1.69115397e-03,  -6.88731223e-02,
#          6.48716986e-02,   3.13963853e-02,   4.10852917e-02,
#         -8.16705972e-02,  -1.73979387e-01,   1.07712492e-01,
#         -1.97330564e-02,   5.16431741e-02,   7.05659762e-02,
#          3.05805430e-02,   1.89493515e-03,   9.98424366e-02,
#         -8.82055536e-02,  -5.90157043e-03,  -3.52458581e-02,
#         -2.43024994e-02,  -2.94785332e-02], dtype=float32)

# %%
words[:5]
# Out:
# ['the', 'of', 'and', 'one', 'in']

# %%
num_points
# Out:
# 400

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
